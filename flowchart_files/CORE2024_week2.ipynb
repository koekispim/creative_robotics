# %% [markdown]
# # Workshop 6: Exchanging data, Git setup</font> </u>

# %% [markdown]
# ## Exchanging data: Reading data from and writing data to files
#
# When working on group projects, your team can encounter various challenges in terms of collaboration. For instance, your project can consist of different components (e.g. written in both GHPython and VSCode). It can be challenging to integrate these different components. One way to do so is by exchanging data between them.

# %% [markdown]
# # **Sharing Code with Git**
# Work out the problems in this notebook and each collaborator committs their branch to the main repository.

# %% [markdown]
# Read more about Git workflow in VS Code: https://code.visualstudio.com/docs/sourcecontrol/overview

# %% [markdown]
# # **Exercises: Convert bubble diagrams into functional codes**

# %% [markdown]
# Flowcharts, are the blueprint of a code. The same way architects need drawings and models in order to process complex spacial information, developper uses flowcharts to keep control over their program. There are some rule to follow when making a flowchart, however you can also add personal feature to it. Here are the elements to use in a flowchart:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Flowchart can have different shapes, but the logic reamains the same. In general, flowcharts follow this generic logic:<br><br>
# ![flow-shape-2.png](images\flow-shape-2.jpg)

# %% [markdown]
# Here you can find a flowchart of a basic comparison between A and B:<br><br>
# ![](images\flow-conditional.jpg)

# %% [markdown]
# On the next image you can find a general for of how to make a for loop in a flowchart. Below that you will find a nested for loop (or double for loop).<br><br>
#
# ![](images\flow-loop.jpg)

# %% [markdown]
# Next you will find some very famous and fundamental algorithms that are almost always present within the functions that are used for all kind of programming. In order to get to know them and to train how to make flowcharts, we will see the python code of some sorting algorithms and you will get the task to make the flowcharts for those algorithms.
# <br>
#
# <br>

# %% [markdown]
# **Bubble Sort:**

# %%
def bubbleSort(arr):
    n = len(arr)-1


    # Traverse through all array elements
    for i in range(n):

        for j in range(0, n-i):

            # traverse the array from 0 to n-i
            # Swap if the element found is greater
            # than the next element
            if arr[j] > arr[j + 1]:
                temp = arr[j]
                arr[j] = arr[j+1]
                arr[j+1] = temp


# Driver code to test above
arr = [64, 34, 25, 12, 22, 11, 90]
print(arr)
bubbleSort(arr)
print(arr)
# Out:
# [64, 34, 25, 12, 22, 11, 90]
# [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# **Bubble Sort**

# %% [markdown]
# ![](images/bubble-sort.jpg)

# %% [markdown]
# **Insertion Sort**

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

# Example usage
arr = [12, 11, 13, 5, 6]
insertion_sort(arr)
print(arr)
# Out:
# [5, 6, 11, 12, 13]

# %% [markdown]
# ![](images/insertion-sort.jpg)

# %% [markdown]
# **WHAT EACH COLOR/SHAPE MEANS:**
# <br><br>
# ![](images\exercises\flow_shapes.png)

# %% [markdown]
# ### **Flowchart Exercise 1:**
# <br><br>
# ![](images\exercises\flowchart\exercise_1.png)

# %%
"""✏️ADD YOUR SOLUTIONS ON A NEW .PY FILE✏️"""
def exercise1(output):
    print(output)

exercise1('hello')
# Out:
# hello

# %% [markdown]
# ### **Flowchart Exercise 2:**
# <br><br>
# ![](images/exercises/flowchart/exercise_2.png)

# %%
"""✏️ADD YOUR SOLUTIONS ON A NEW .PY FILE✏️"""

# %% [markdown]
# ### **Flowchart Exercise 3:**
# <br><br>
# ![](images/exercises/flowchart/exercise_3.png)

# %%
"""✏️ADD YOUR SOLUTIONS ON A NEW .PY FILE✏️"""
def flowchart3(input):
    if input > 0:
        print('Greater than 0')
    else:
        pass

flowchart3(eval(input('Enter a number')))
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\koenh\Documents\GitHub\creative_robotics\.venv_git\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[14], line 8
#     flowchart3(eval(input('Enter a number')))
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### **Flowchart Exercise 4:**
# <br><br>
# ![](images/exercises/flowchart/exercise_4.png)

# %%
"""✏️ADD YOUR SOLUTIONS ON A NEW .PY FILE✏️"""
